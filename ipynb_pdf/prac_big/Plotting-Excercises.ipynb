# %%
# %%html
# <style>
# .question{
#     background: #99ffff;
#     border: solid 1px #1356ff;
#     border-radius: 3px;
#     padding: 2px;
# }
# .question>code {background: #e8ffff;border: solid 1px #83aab7;}
# .warning {background: #ffadad;}
# .Q{font-weight: bold;}
# </style>
# Out:
# <style>
# .question{
#     background: #99ffff;
#     border: solid 1px #1356ff;
#     border-radius: 3px;
#     padding: 2px;
# }
# .question>code {background: #e8ffff;border: solid 1px #83aab7;}
# .warning {background: #ffadad;}
# .Q{font-weight: bold;}
# </style>

# %% [markdown]
# ### Rules
# 1. <font class="warning">Do not change the cells above</font>
# 2. The questions that you need to solve will have a <font class="question">blue background</font>, you only need to change the part that says `## TODO: Complete Code ##` inside code cells

# %% [markdown]
# <hr />

# %% [markdown]
# # Plotting Exercises

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# <p class="question"><span class="Q">Q.1</span> First, you need to import the data, import the file <code>01-wine-quality.csv</code> using pandas by completing the following code:</p>

# %%
df = pd.read_csv('01-wine-quality.csv', encoding='utf-8-sig')

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.6             0.400         0.32             1.7      0.035
# 1            5.2             0.240         0.15             7.1      0.043
# 2            8.9             0.840         0.34             1.4      0.050
# 3            5.8             0.330         0.23             5.0      0.053
# 4            7.1             0.360         0.24             1.8      0.025
# 5            7.1             0.130         0.29            15.5      0.064
# 6            7.2             0.170         0.34             6.4      0.042
# 7            7.4             0.660         0.00             1.8      0.075
# 8            6.2             0.220         0.27             1.5      0.064
# 9            5.4             0.835         0.08             1.2      0.046
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# <p class="question"><span class="Q">Q.2</span> Create a new dataframe called <code>red</code> that contains only the red wine records:</p>

# %%
## TODO: Complete Code ##
red = df[df['type'] == 'red']

# %%
red.head(10)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2             8.9             0.840         0.34             1.4      0.050
# 7             7.4             0.660         0.00             1.8      0.075
# 9             5.4             0.835         0.08             1.2      0.046
# 10            7.5             0.610         0.26             1.9      0.073
# 11            8.1             0.670         0.55             1.8      0.117
# 16            6.8             0.690         0.00             5.6      0.124
# 18           10.2             0.410         0.43             2.2      0.110
# 19            7.4             0.600         0.26             7.3      0.070
# 20            7.2             0.250         0.37             2.5      0.063
# 21            9.7             0.550         0.17             2.9      0.087
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# <p class="question"><span class="Q">Q.3</span> Create a new dataframe called <code>white</code> that contains only the white wine records:</p>

# %%
## TODO: Complete Code ##
white = df[df['type'] == 'white']

# %%
white.head(10)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             6.6              0.40         0.32            1.70      0.035
# 1             5.2              0.24         0.15            7.10      0.043
# 3             5.8              0.33         0.23            5.00      0.053
# 4             7.1              0.36         0.24            1.80      0.025
# 5             7.1              0.13         0.29           15.50      0.064
# 6             7.2              0.17         0.34            6.40      0.042
# 8             6.2              0.22         0.27            1.50      0.064
# 12            7.9              0.16         0.74           17.85      0.037
# 13            8.2              0.17         0.32            1.50      0.050
# 14            7.8              0.39         0.26            9.90      0.059
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# <p class="question"><span class="Q">Q.4</span> Plot the heatmap of the correlation matrix for <code>df</code>, <code>red</code> and <code>white</code></p>

# %%
fig = plt.figure(figsize=(10,7))
## TODO: Complete Code ##
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt='.2f', square=True, cmap='coolwarm')
plt.show()

# %%
fig = plt.figure(figsize=(10,7))
## TODO: Complete Code ##
sns.heatmap(red.corr(numeric_only=True), annot=True, fmt='.2f', square=True, cmap='coolwarm')
plt.show()

# %%
fig = plt.figure(figsize=(10,7))
## TODO: Complete Code ##
sns.heatmap(white.corr(numeric_only=True), annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.show()

# %% [markdown]
# <p class="question"><span class="Q">Q.5</span> Plot the Pair Plot from <code>df</code> for the columns <code>fixed acidity</code>, <code>density</code>, <code>total sulfur dioxide</code>, <code>alcohol</code>, <code>quality</code>, and <code>pH</code>. The plot should show a different color for every <code>type</code></p>

# %%
## TODO: Complete Code ##
sns.pairplot(df[['fixed acidity', 'density', 'total sulfur dioxide', 'alcohol', 'quality', 'pH', 'type']], hue='type')

# %% [markdown]
# <p class="question"><span class="Q">Q.6</span> Add a new column to <code>df</code>, call it <code>red</code>, the column should contain <code>True</code> or <code>1</code> if the record has <code>type=red</code> and <code>False</code> or <code>0</code> otherwise</p>

# %%
## TODO: Complete Code ##
df['red'] = df['type'] == 'red'

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.6             0.400         0.32             1.7      0.035
# 1            5.2             0.240         0.15             7.1      0.043
# 2            8.9             0.840         0.34             1.4      0.050
# 3            5.8             0.330         0.23             5.0      0.053
# 4            7.1             0.360         0.24             1.8      0.025
# 5            7.1             0.130         0.29            15.5      0.064
# 6            7.2             0.170         0.34             6.4      0.042
# 7            7.4             0.660         0.00             1.8      0.075
# 8            6.2             0.220         0.27             1.5      0.064
# 9            5.4             0.835         0.08             1.2      0.046
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# <p class="question"><span class="Q">Q.7</span> Plot the new heatmap of the correlation matrix of <code>df</code></p>

# %%
fig = plt.figure(figsize=(10,7))
## TODO: Complete Code ##
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.show()

# %% [markdown]
# <p class="question"><span class="Q">Q.8</span> Plot Box Plot of the <code>density</code>, differ between red and white wine records on the same plot</p>

# %%
## TODO: Complete Code ##
sns.boxplot(data=df, x='type', y='density')
# Out:
# <Axes: xlabel='type', ylabel='density'>

# %% [markdown]
# <p class="question"><span class="Q">Q.9</span> Plot Box Plot of the <code>total sulfur dioxide</code>, differ between red and white wine records on the same plot</p>

# %%
## TODO: Complete Code ##
sns.boxplot(data=df, x='type', y='total sulfur dioxide')
# Out:
# <Axes: xlabel='type', ylabel='total sulfur dioxide'>

# %% [markdown]
# <p class="question"><span class="Q">Q.10</span> Plot the Line Plot that shows the relationship between <code>alcohol</code> and <code>density</code> for the records that have <code>quality>6</code></p>

# %%
## TODO: Complete Code ##
df_high = df[df['quality'] > 6]
sns.scatterplot(data=df_high, x='alcohol', y='density')
# Out:
# <Axes: xlabel='alcohol', ylabel='density'>
