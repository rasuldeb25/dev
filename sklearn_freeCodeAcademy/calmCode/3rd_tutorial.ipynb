# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
# number of samples
n = 500
# generate random x and y values
x = np.random.randint(0, 300, size=n)
y = np.random.randint(0, 300, size=n)
# generate labels "a" or "b"
z = np.random.choice(["a", "b"], size=n)
# build dataframe
df = pd.DataFrame({
    "x": x,
    "y": y,
    "z": z
})
# save to CSV
df.to_csv("drawndata1.csv", index=False)

# %%
df = pd.read_csv("C:/dev/sklearn_freeCodeAcademy/calmCode/01-wine-quality.csv")
df.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.6              0.40         0.32             1.7      0.035
# 1            5.2              0.24         0.15             7.1      0.043
# 2            8.9              0.84         0.34             1.4      0.050
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 39.0                  84.0  0.99096  3.59       0.48
# 1                 32.0                 134.0  0.99378  3.24       0.48
# 2                  4.0                  10.0  0.99554  3.12       0.48
#
#    alcohol  quality   type
# 0     12.7        7  white
# 1      9.9        6  white
# 2      9.1        6    red

# %%
red = df[df['type'] == 'red']
red.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2            8.9             0.840         0.34             1.4      0.050
# 7            7.4             0.660         0.00             1.8      0.075
# 9            5.4             0.835         0.08             1.2      0.046
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2                  4.0                  10.0  0.99554  3.12       0.48
# 7                 13.0                  40.0  0.99780  3.51       0.56
# 9                 13.0                  93.0  0.99240  3.57       0.85
#
#    alcohol  quality type
# 2      9.1        6  red
# 7      9.4        5  red
# 9     13.0        7  red

# %%
# we are dropping type, cuz it is already sorted to only reds, we drop quality cuz, it is our target (the feature we wanna predict)
X = red.drop(columns=['quality', 'type']).values
y = red['quality'].values #regression (continues values)
# y = (red["quality"] >=7).astype(int) #classification

X_new = StandardScaler().fit_transform(X)

# %%
X1 = red['alcohol'].values
X2 = red['sulphates'].values
y  = red['quality'].values

plt.scatter(X1, X2, c=y, cmap='viridis')
plt.xlabel("Alcohol")
plt.ylabel("Sulphates")
plt.colorbar(label="Quality")
