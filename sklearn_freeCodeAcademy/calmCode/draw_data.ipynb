# %%
from drawdata import ScatterWidget

widget = ScatterWidget()
widget

# %%
widget.data_as_pandas
# Out:
#               x           y    color label  batch
# 0    159.857731  399.159116  #1f77b4     a      0
# 1    164.309441  397.478030  #1f77b4     a      0
# 2    158.809441  393.850589  #1f77b4     a      0
# 3    159.251028  392.158023  #1f77b4     a      0
# 4    155.665801  383.374707  #1f77b4     a      0
# ..          ...         ...      ...   ...    ...
# 822  252.223950   24.866942  #ff7f0e     b     27
# 823  239.779757   20.823196  #ff7f0e     b     28
# 824  224.734462   23.968857  #ff7f0e     b     29
# 825  223.846931   22.861349  #ff7f0e     b     29
# 826  219.807523   19.664195  #ff7f0e     b     29
#
# [827 rows x 5 columns]

# %%
import matplotlib.pylab as plt

df = widget.data_as_pandas
plt.scatter(df['x'], df['y'], color=df['color'])

# %%
from drawdata import BarWidget

widget = BarWidget(collection_names=["usage", "sunshine"], n_bins=24)
widget

# %%
from ipycanvas import Canvas

canvas = Canvas(width=600, height=400)
canvas.free_drawing = True
canvas
# Out:
# Canvas(height=400, width=600)

# %%
canvas.fill_style = "red"
canvas.fill_rect(10, 10, 50, 50)
canvas
# Out:
# Canvas(height=200, width=300)
